# %% [markdown]
# # Visual Studio Jupyter Notebook Support

# %%
msg = "hello world"
print(msg)
# Out:
# hello world

# %%
import matplotlib.pyplot as plt
import numpy as np 
t = np.arange (0.,5.,0.2) 
plt.plot(t, t, 'r--', t**3, 'bs', t, t**2, 'g^')
plt.show()

# %% [markdown]
# ## theres a lot to think about here
# 1. cannot get access sudo functions in terminal - eg htpassword
# 2. I have received an email from GoDaddy saying that my new hosted site (learn-tech.co) cannot be backed up
# 3. I have both a http and an https site - thought (and wanted) just a https site
# ![image](1.gif)
